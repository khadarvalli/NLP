# %% [markdown]
# ## Feature Extraction.

# %% [markdown]
# - Example1 :- Apple is looking at buying U.K. Startup for $1 Billions.
# - Example2 :- Ishu ate the apple.

# %% [markdown]
# In the both having the common name is Apple and Both name having the different meaning.

# %% [markdown]
# ## Architecture Of SpaCy.

# %% [markdown]
# SpaCy having the main to in It's Architures that is the
# - 1:- Document.
# - 2:-  vocabulary
#
# - The central data structures in spaCy are the Doc and the Vocab. The Doc object owns the sequence of tokens and all their annotations. The Vocab object owns a set of look-up tables that make common information available across documents. By centralizing strings, word vectors and lexical attributes, we avoid storing multiple copies of this data. This saves memory, and ensures there’s a single source of truth.

# %%
from IPython.display import Image
Image('C:/Users/Microsoft/Downloads/spacy.png')

# %% [markdown]
# - **Tokenization :-** Segmenting the Text in words,punctuations markes etc.It beaking the the in small small entity.
# - **Part-Of-Speech Tagging :-**  Assigning the words types to tokens like verbs and nouns.Use the Grammer.
# - **Dependecy Parsering :-** Assigning syntactic dependency labels,describing the relationship between individual token like Subject or Object.It is help to find the dependency.
# - **Lemmitization :-** Assigning the base form of words.For an example the lemma of 'was' is be and the lemma of rats is rat.
# - **Text Boundary Detection :-** Finding and Segmenting individual Sentences.
# - **Named entity recognition :-** Lebelling the 'Real World Object' like person,companies and locations.
# - **Entity Linking  :-** Disambinguating textual entity to the unique identifiers in a Knowledge Base.
# - **Similarity :-** Comparing the words,text and document according to the find the similarity inbetween them.It will find the similarity like cats and dogs the pet animal and if compare with them banana then there will be desimilarity.
# - **Text Classification :-** Assigning the categories or label to whole document or parts of the documents.
# - **Rule Based matching :-** Finding the sequence of token based on their text and linguistic annotations,similar to the regular expressions.
# - **Training :-** Updating and Improving a statstical model's predictions.
# - **Serialization :-** Saving the object to file or byte strings.

# %% [markdown]
# **Spacy Models :-** https://spacy.io/models/en

# %%
#!pip install -U spacy-lookups-data

# %%
#!pip install -U spacy

# %%
#!python -m spacy download en_core_web_sm

# %% [markdown]
# **Processing of the raw text intelligently is difficult :Most of the  words are rare,And it's  common for words that look completly different to mean almost the same thing.**

# %% [markdown]
# In the natural processing the accuracy can not obtain the 100 % becasue the text is is more difficult to precess accurately.Spacy doen't garanteed that tokenization and meaning of the words will annoted or classified exacly.From that we can say the It will give us garantee  of the accuracies.

# %% [markdown]
# If the spacy doen't any we can add our rule to classify the text.
#
# `That's exactly what Spacy is design to do : You put in raw text,and get Back a DOC object,Comes with Variety of annotations.`

# %% [markdown]
# # Tokenization
#
# Tokenization is the task of spiliting a text into the meaningful segments,called tokens.The input to be the tokenizer is a unicode text,and the output is a Doc Object.
#
# e.g.Ishu ate the apple.
#
# - In the above sentence the tokenization can be done as `Ishu`,`ate`,`the`,`apple.`
# - In this Tokenization,It will first give attention to the spaces and at the last it focus of the `!` `,` `.` and other special chareters.

# %%
import spacy   #import spacy

# %%
nlp = spacy.load('en_core_web_sm')   #This is pretrained model through which we can we get the more info like
#Vocabulary, syntax, entities, vectors and written text (blogs, news, comments)

# %%
doc = nlp('Apple is looking at buying U.K. startup for $1 billion')

# %%
#Tokentization-- take input as raw text and then covert into the document

# %%
for token in doc:
    print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %%
doc = nlp("Apple isn't looking at buying U.K. startup for $1 billion.")

# %%
for token in doc:
    print(token.text)
# Out:
# Apple
# is
# n't
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion
# .

# %% [markdown]
# This is how the spacy is smart it itdentify where we should have to put stopword.

# %% [markdown]
# # Tagger.(Part-of_Speech Tagging.)
# - In the we will gonna use some grammer.Spacy having already dictionary or voculary to identify the grammer.It is syntactic analysis.

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 billion.

# %%
for token in doc:
    print(token.text,'                    ',token.lemma_)
    
    
#With the help of lemitaization we can compress the our text file.Here we can the n number of worlds are avalible.It bringing
#Them to the root word.It will consume the less space.
# Out:
# Apple                      Apple
# is                      be
# n't                      not
# looking                      look
# at                      at
# buying                      buy
# U.K.                      U.K.
# startup                      startup
# for                      for
# $                      $
# 1                      1
# billion                      billion
# .                      .

# %%
for token in doc:
    print(f'{token.text:{30}} {token.lemma_:{30}} {token.pos_ :{40}} {token.is_stop}')
    
#for human readable we use the _after the name
#we also know the stopwords that are the i.e. the,a,an and so on thses stop doent put more information.
# Out:
# Apple                          Apple                          PROPN                                    False
# is                             be                             AUX                                      True
# n't                            not                            PART                                     True
# looking                        look                           VERB                                     False
# at                             at                             ADP                                      True
# buying                         buy                            VERB                                     False
# U.K.                           U.K.                           PROPN                                    False
# startup                        startup                        NOUN                                     False
# for                            for                            ADP                                      True
# ...

# %% [markdown]
# If you see above the Apple is pronaun and It is not stop word.

# %% [markdown]
# # Dependency  Parsing.

# %% [markdown]
# It we tell us that how much the each token is related each other.

# %%
for chunk in doc.noun_chunks:
    print(f'{chunk.text :{30}} {chunk.root.text:{15}}  {chunk.root.dep_}')
# Out:
# Apple                          Apple            nsubj
# U.K. startup                   startup          dobj

# %% [markdown]
# # Name Entity Recognition.

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 billion.

# %%
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Apple ORG
# U.K. GPE
# $1 billion MONEY

# %% [markdown]
# # Sentence Segmenetation.

# %% [markdown]
# Setence segmentation is like segment the setence on the spacy kownledge.We can say that it will perfect segmentation.

# %% [markdown]
# - doc.sents

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 billion.

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Apple isn't looking at buying U.K. startup for $1 billion.

# %%
doc1 = nlp('Hi i am Roshan and I am watching Cricket match. MI will win today.')

# %%
for sent in doc1.sents:
    print(sent)
# Out:
# Hi i am Roshan
# and I am watching Cricket match.
# MI will win today.

# %%
doc2 = nlp('Hi i am Roshan and I am watching Cricket match. MI .. win today!.')

# %%
for sent in doc2.sents:
    print(sent)
# Out:
# Hi i am Roshan
# and I am watching Cricket match.
# MI .. win today!.

# %% [markdown]
# **Customized Segmentation of the sentence.**

# %% [markdown]
# Customization of the sentences in nothing but the break as per our requirement by applying the set of rule.

# %%
document = nlp('Hi Ravi tell me somethig......what......No i am not joking!')

# %%
nlp.remove_pipe('set_rule')
# Out:
# ('set_rule', <function __main__.set_rule(doc)>)

# %%
nlp.add_pipe(set_rule,before='parser')

# %%
def set_rule(doc):
    for token in doc[:-1]:
        if token.text =='.....':
            doc[token.i +1].is_sent_start=True
    return doc

# %%
for sent in  document.sents:
    print(sent)
# Out:
# Hi Ravi tell me somethig......
# what......
# No i am not joking!

# %%
sentence = "Geomentry is the best subject.... to learn but sometime i get bore.55..aAman...233"

# %%
do = nlp(sentence)

# %%
do
# Out:
# Geomentry is the best subject.... to learn but sometime i get bore.55..aAman...233

# %%
for sent in do.sents:
    print(sent)
# Out:
# Geomentry is the best subject....
# to learn but sometime i get bore.55..
# aAman...233

# %%
def set_rule(doc):
    for token in doc[:-1]:
        if token.text =='...233':
            doc[token.i +1].is_sent_start = True
    return doc

# %%
nlp.remove_pipe('set_rule')
# Out:
# ('set_rule', <function __main__.set_rule(doc)>)

# %%
nlp.add_pipe(set_rule,before='parser')

# %%
for sent in do.sents:
    print(sent)
# Out:
# Geomentry is the best subject....
# to learn but sometime i get bore.55..
# aAman...233

# %% [markdown]
# # Visualization.

# %%
from spacy import displacy

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 billion.

# %%
displacy.render(doc,style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="42f5a040d11547fcb09265d838eee37e-0" class="displacy" width="2150" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
displacy.render(doc,style='dep',options={'compact':True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2a6e9ef259e44464a9a81e6958d44e69-0" class="displacy" width="1850" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
displacy.render(doc,style='dep',options={'compact':True,'distance':100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1b55cde7671743a4aaaf7cc914551b2f-0" class="displacy" width="1250" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
# ...

# %%
displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  isn't looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
# ...

# %% [markdown]
# ## Thank You !
